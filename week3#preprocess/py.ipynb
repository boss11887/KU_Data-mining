# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('adult.csv')

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status
# 0   25    Private  226802          11th                7       Never-married  \
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss
# 0  Machine-op-inspct    Own-child  Black    Male             0             0  \
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
#Categoriacal
ax = sns.histplot(data=df['workclass'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
ax = sns.histplot(data=df['education'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
ax = sns.histplot(data=df['marital-status'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
ax = sns.histplot(data=df['occupation'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
ax = sns.histplot(data=df['relationship'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
ax = sns.histplot(data=df['race'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
ax = sns.histplot(data=df['gender'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
ax = sns.histplot(data=df['native-country'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
ax = sns.histplot(data=df['income'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
# Out:
# /var/folders/vf/jq_971311pb5z07q8l6450ww0000gn/T/ipykernel_19039/3008175025.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# /var/folders/vf/jq_971311pb5z07q8l6450ww0000gn/T/ipykernel_19039/3008175025.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# /var/folders/vf/jq_971311pb5z07q8l6450ww0000gn/T/ipykernel_19039/3008175025.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# /var/folders/vf/jq_971311pb5z07q8l6450ww0000gn/T/ipykernel_19039/3008175025.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# ...

# %%
#Numberical
sns.histplot(data=df['age'],bins=10)
plt.show()
sns.histplot(data=df['hours-per-week'],bins=10)
plt.show()

# %%
#PART C
y=df['income']

name="workclass"
x=df[name]
data= pd.DataFrame({'income': y, name: x})
ax = sns.countplot(x=name,hue='income',data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()


name="education"
x=df[name]
data= pd.DataFrame({'income': y, name: x})
ax = sns.countplot(x=name,hue='income',data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()


name="marital-status"
x=df[name]
data= pd.DataFrame({'income': y, name: x})
ax = sns.countplot(x=name,hue='income',data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()


name="occupation"
x=df[name]
data= pd.DataFrame({'income': y, name: x})
ax = sns.countplot(x=name,hue='income',data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()

name="relationship"
x=df[name]
data= pd.DataFrame({'income': y, name: x})
ax = sns.countplot(x=name,hue='income',data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()


name="race"
x=df[name]
data= pd.DataFrame({'income': y, name: x})
ax = sns.countplot(x=name,hue='income',data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()


name="gender"
x=df[name]
data= pd.DataFrame({'income': y, name: x})
ax = sns.countplot(x=name,hue='income',data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()


name="native-country"
x=df[name]
data= pd.DataFrame({'income': y, name: x})
ax = sns.countplot(x=name,hue='income',data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()

name="income"
x=df[name]
data= pd.DataFrame({'income': y, name: x})
ax = sns.countplot(x=name,hue='income',data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
# workclass
# education
# martial-status
# occupation
# relationship
# race
# gender
# native-country
# income

# %%
#PART D
numerical_data= pd.DataFrame({
    'age':df['age'],
    'fnlwgt':df['fnlwgt'],
    'educational-num':df['educational-num'],
    'capital-gain':df['capital-gain'],
    'capital-loss':df['capital-loss'],
    'hours-per-week':df['hours-per-week']}

)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
statistics = numerical_data.describe().to_string()
print(statistics)
print()
print(numerical_data.median())
# Out:
#            age     fnlwgt  educational-num  capital-gain  capital-loss  hours-per-week
# count 48842.00   48842.00         48842.00      48842.00      48842.00        48842.00
# mean     38.64  189664.13            10.08       1079.07         87.50           40.42
# std      13.71  105604.03             2.57       7452.02        403.00           12.39
# min      17.00   12285.00             1.00          0.00          0.00            1.00
# 25%      28.00  117550.50             9.00          0.00          0.00           40.00
# 50%      37.00  178144.50            10.00          0.00          0.00           40.00
# 75%      48.00  237642.00            12.00          0.00          0.00           45.00
# max      90.00 1490400.00            16.00      99999.00       4356.00           99.00
#
# age                   37.00
# fnlwgt            178144.50
# educational-num       10.00
# capital-gain           0.00
# capital-loss           0.00
# hours-per-week        40.00
# dtype: float64

# %%
#PART E

y=df['income']

for column_name in numerical_data.columns:
    #print("Column Name:", column_name)
    x=df[column_name]
    data= pd.DataFrame({'income': y, column_name: x})

    #print(data)
    ax = sns.histplot(data=data,x=column_name,hue='income')
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    plt.show()
    
    #print()

# %%
#PART E
mydata = numerical_data.drop('fnlwgt', axis=1)

y=df['income']
use=[]
for c1 in mydata.columns:
    use.append(c1)
    for c2 in mydata.columns:
        if c2 in use:
            continue
        if c1 == c2:
            continue
        x=df[c1]
        y=df[c2]

        ax = sns.scatterplot(x=x,y=y)
        plt.show()

print(mydata)
# Out:
#        age  educational-num  capital-gain  capital-loss  hours-per-week
# 0       25                7             0             0              40
# 1       38                9             0             0              50
# 2       28               12             0             0              40
# 3       44               10          7688             0              40
# 4       18               10             0             0              30
# ...    ...              ...           ...           ...             ...
# 48837   27               12             0             0              38
# 48838   40                9             0             0              40
# 48839   58                9             0             0              40
# 48840   22                9             0             0              20
# 48841   52                9         15024             0              40
#
# [48842 rows x 5 columns]

# %%
one_hot_encoded = pd.get_dummies(df['workclass'])
one_hot_encoded.head()
# Out:
#        ?  Federal-gov  Local-gov  Never-worked  Private  Self-emp-inc
# 0  False        False      False         False     True         False  \
# 1  False        False      False         False     True         False
# 2  False        False       True         False    False         False
# 3  False        False      False         False     True         False
# 4   True        False      False         False    False         False
#
#    Self-emp-not-inc  State-gov  Without-pay
# 0             False      False        False
# 1             False      False        False
# 2             False      False        False
# 3             False      False        False
# 4             False      False        False

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
columns_to_scale = ['educational-num']
scaled_data = scaler.fit_transform(df[columns_to_scale])
scaled_df = pd.DataFrame(scaled_data, columns=columns_to_scale)

print(scaled_df)
# Out:
#        educational-num
# 0                 0.40
# 1                 0.53
# 2                 0.73
# 3                 0.60
# 4                 0.60
# ...                ...
# 48837             0.73
# 48838             0.53
# 48839             0.53
# 48840             0.53
# 48841             0.53
#
# [48842 rows x 1 columns]

# %%
print(df[columns_to_scale])
# Out:
#        educational-num
# 0                    7
# 1                    9
# 2                   12
# 3                   10
# 4                   10
# ...                ...
# 48837               12
# 48838                9
# 48839                9
# 48840                9
# 48841                9
#
# [48842 rows x 1 columns]
